# %%
# -------------------------------------------------------------------------------------- #
# ---------- DISCRETE DIPOLE METHOD FOR UV-VIS CALCULATIONS FROM DIPOLE DATA ----------- #
# -------------------------------------------------------------------------------------- #
import os
import json
import pathlib
import numpy as np
import pandas as pd
from dda_complex128 import DDA
import tensorflow as tf
import fresnel
from matplotlib import pyplot as plt
def delete_1D(new_position,position):
    A=np.array(np.around(new_position,7)).tolist()
    B=np.array(np.around(position,7)).tolist()
    A = [i for i in A if i not in B]
    return A
# Out:
# 2022-02-24 09:05:44.887452: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1

# %%
# GPU Device Config
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   
os.environ["CUDA_VISIBLE_DEVICES"]="0"
current_folder_path = pathlib.Path().absolute()

# %%
# get the initial dipole position
position = []
for x in range(-100,100):
    for y in range(-100,100):
        for z in range(-100,100):
            if abs(x)+abs(y)+abs(z)<=16:
                position.append([x,y,z])
position = np.array(position)
scene = fresnel.Scene()
geometry = fresnel.geometry.Sphere(scene, N=len(position), radius=np.sqrt(2)/2)
geometry.position[:] = position
geometry.material = fresnel.material.Material(color=fresnel.color.linear([0.9, 0.714, 0.169]), roughness = 0.2)
scene.camera = fresnel.camera.Orthographic.fit(scene)
fresnel.preview(scene)

np.savetxt('./data1/dipoles.csv',position,delimiter=',')

# %% [markdown]
# # Benchmark from tiny cube to growth into nanorods

# %%
data_path = "./data1"
# define the intial and final dipole sets
config = {'gpu_device': '/GPU:0',
            'dipole_length': 0.41,
            'min_wavelength': 0.45,
            'max_wavelength': 0.70,
            'num_wavelengths': 26,
            'ref_medium': 1.333,
            'rotation_steps': 10,
            'folder_path': data_path,
            'calculate_electricField': False,
            'ref_data': [str(current_folder_path) + '/Au_ref_index.csv',str(current_folder_path) + '/Ag_ref_index.csv'],
            'metals': ["Au","Ag"],
            'dipole_data': str(current_folder_path) + '/data1/dipoles.csv',
            "ratio":[1.0, 0],
            "lattice_constant":0.41,
            "method":"homo",
            "atom_data":None
           }

# %%
changed_dipole_index = [int(i) for i in np.loadtxt('./data1/changed_dipole_index.csv',delimiter=',')]
changed_dipole_type = np.loadtxt('./data1/changed_dipole_type.csv',delimiter=',')

# %%
rate = 10**6
np_dda = DDA(config)
alpha_j1 = np.array([np.repeat(np_dda.alpha_j[:,i],3) for i in range(np_dda.alpha_j.shape[1])]).T
alpha_j2 = np.array([np.repeat(np_dda.alpha_j[:,i],3)/rate for i in range(np_dda.alpha_j.shape[1])]).T

extra_index = [int(i) for i in changed_dipole_index]
atom_index = [[i for i in range(3*j,3*j+3)] for j in extra_index]
atom_index = np.array(atom_index).flatten().tolist()

np_dda.flip_infor = [atom_index,alpha_j1,alpha_j2]
# Out:
# Reading refractive index and dipole data
# Calculating radius of the cross section and polarizability

# %%
t_total = np_dda.calculate_spectrum_trajectories_v2_1()
t_total = np.array(t_total)
np.savetxt(data_path+f'/data_rod_growth2_t_{rate}_128_test.csv',t_total,delimiter=',')
np.savetxt(data_path+f'/C_cross_total2_{rate}_128_test.csv',np.array(np_dda.C_cross_total),delimiter=',')
# Out:
# 0
# 2022-02-22 15:10:08.848664: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2022-02-22 15:10:08.849732: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2022-02-22 15:10:08.884686: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:41:00.0 name: NVIDIA RTX A6000 computeCapability: 8.6
# coreClock: 1.8GHz coreCount: 84 deviceMemorySize: 47.54GiB deviceMemoryBandwidth: 715.34GiB/s
# 2022-02-22 15:10:08.884734: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2022-02-22 15:10:08.886187: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2022-02-22 15:10:08.886229: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.10
# 2022-02-22 15:10:08.887448: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2022-02-22 15:10:08.887703: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2022-02-22 15:10:08.888892: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2022-02-22 15:10:08.889361: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.10
# 2022-02-22 15:10:08.891852: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2022-02-22 15:10:08.894530: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# 2022-02-22 15:10:08.895493: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-02-22 15:10:08.905489: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2022-02-22 15:10:08.906941: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:41:00.0 name: NVIDIA RTX A6000 computeCapability: 8.6
# coreClock: 1.8GHz coreCount: 84 deviceMemorySize: 47.54GiB deviceMemoryBandwidth: 715.34GiB/s
# 2022-02-22 15:10:08.906975: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2022-02-22 15:10:08.906992: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2022-02-22 15:10:08.907002: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.10
# 2022-02-22 15:10:08.907012: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2022-02-22 15:10:08.907021: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2022-02-22 15:10:08.907030: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2022-02-22 15:10:08.907039: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.10
# 2022-02-22 15:10:08.907047: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2022-02-22 15:10:08.909673: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# 2022-02-22 15:10:08.909742: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2022-02-22 15:12:57.432149: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1261] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2022-02-22 15:12:57.432193: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1267]      0
# 2022-02-22 15:12:57.432202: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1280] 0:   N
# 2022-02-22 15:12:57.436665: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1406] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 44921 MB memory) -> physical GPU (device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:41:00.0, compute capability: 8.6)
# 2022-02-22 15:12:57.815460: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 579268624 exceeds 10% of free system memory.
# 2022-02-22 15:12:58.089094: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 579268624 exceeds 10% of free system memory.
# 2022-02-22 15:12:58.239777: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2022-02-22 15:14:23.425551: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 579268624 exceeds 10% of free system memory.
# 2022-02-22 15:14:23.659749: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 579268624 exceeds 10% of free system memory.
# 2022-02-22 15:14:23.934425: I tensorflow/core/util/cuda_solvers.cc:180] Creating CudaSolver handles for stream 0x55deb35a5060
# 2022-02-22 15:14:23.934633: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2022-02-22 15:15:11.813863: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# tf.Tensor(2.2154404012743787e-05, shape=(), dtype=float64)
# 1
# 2022-02-22 15:53:32.416275: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 579268624 exceeds 10% of free system memory.
# tf.Tensor(2.1843638540362222e-05, shape=(), dtype=float64)
# 2
# tf.Tensor(2.1617804165477965e-05, shape=(), dtype=float64)

# %%
data_path = './data1'
rate = 10**6
data2 = np.loadtxt(data_path+f'/C_cross_total2_{rate}_128_test.csv',delimiter=',')

# %%
for i in range(int(data2.shape[1]/800)):
    plt.plot(np.linspace(0.45,0.7,26),data2[:,800*i])
plt.plot(np.linspace(0.45,0.7,26),data2[:,-1])
plt.show()

# %%
from scipy.interpolate import interp1d
I = []
wv= []
wavelength = np.linspace(0.45,0.70,26)
sample_wavlength = np.linspace(0.45,0.7,1000)
for i in range(int(data2.shape[1])):
    f = interp1d(wavelength, data2[:,i],'cubic')
    I.append(f(sample_wavlength).max())
    wv.append(sample_wavlength[f(sample_wavlength) == f(sample_wavlength).max()])
plt.plot(I)
plt.show()

plt.plot(wv)
plt.show()

# %% [markdown]
# # Benchmark directly with the final structure

# %%
# get the initial dipole position
Au_dipoles = np.ones(len(position),dtype = bool)
for i in range(len(changed_dipole_index)):
    if changed_dipole_type[i] == 1:
        Au_dipoles[changed_dipole_index[i]] = True
    else:
        Au_dipoles[changed_dipole_index[i]] = False

# %%
scene = fresnel.Scene()
geometry = fresnel.geometry.Sphere(scene, N=len(np.array(position)[Au_dipoles]), radius=np.sqrt(2)/2)
geometry.position[:] = np.array(position)[Au_dipoles]
geometry.material = fresnel.material.Material(color=fresnel.color.linear([0.9, 0.714, 0.169]), roughness = 0.2)
scene.camera = fresnel.camera.Orthographic.fit(scene)
fresnel.preview(scene)

# %%
np.savetxt('./data1/final_dipoles.csv',position[Au_dipoles],delimiter=',')

# %%
data_path = "./data1"
# define the intial and final dipole sets
config = {'gpu_device': '/GPU:0',
            'dipole_length': 0.41,
            'min_wavelength': 0.4,
            'max_wavelength': 0.9,
            'num_wavelengths': 51,
            'ref_medium': 1.333,
            'rotation_steps': 10,
            'folder_path': data_path,
            'calculate_electricField': False,
            'ref_data': [str(current_folder_path) + '/Au_ref_index.csv',str(current_folder_path) + '/Ag_ref_index.csv'],
            'metals': ["Au","Ag"],
            'dipole_data': str(current_folder_path) + '/data/final_dipoles.csv',
            "ratio":[1.0, 0],
            "lattice_constant":0.41,
            "method":"homo",
            "atom_data":None
           }

# %%
np_dda = DDA(config)
np_dda.run_DDA()

# %%
plt.plot(np_dda.C_cross_total)

# %% [markdown]
# # Check the initial structure

# %%
# get the initial dipole position
Au_dipoles = np.ones(len(position),dtype = bool)
scene = fresnel.Scene()
geometry = fresnel.geometry.Sphere(scene, N=len(np.array(position)[Au_dipoles]), radius=np.sqrt(2)/2)
geometry.position[:] = np.array(position)[Au_dipoles]
geometry.material = fresnel.material.Material(color=fresnel.color.linear([0.9, 0.714, 0.169]), roughness = 0.2)
scene.camera = fresnel.camera.Orthographic.fit(scene)
fresnel.preview(scene)
np.savetxt('./data1/initial_dipoles.csv',position[Au_dipoles],delimiter=',')

# %%
data_path = "./data1"
# define the intial and final dipole sets
config = {'gpu_device': '/GPU:0',
            'dipole_length': 0.41,
            'min_wavelength': 0.4,
            'max_wavelength': 0.9,
            'num_wavelengths': 51,
            'ref_medium': 1.333,
            'rotation_steps': 10,
            'folder_path': data_path,
            'calculate_electricField': False,
            'ref_data': [str(current_folder_path) + '/Au_ref_index.csv',str(current_folder_path) + '/Ag_ref_index.csv'],
            'metals': ["Au","Ag"],
            'dipole_data': str(current_folder_path) + '/data1/initial_dipoles.csv',
            "ratio":[1.0, 0],
            "lattice_constant":0.41,
            "method":"homo",
            "atom_data":None
           }

# %%
np_dda = DDA(config)
np_dda.run_DDA()

# %%
plt.plot(np_dda.C_cross_total)
