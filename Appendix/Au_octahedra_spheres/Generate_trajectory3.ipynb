# %%
import networkx as nx
import numpy as np
import itertools as it
import random
import time
import scipy
from matplotlib import pyplot as plt
import fresnel

# %%
np.random.seed(100)
random.seed(100)

# %%
def coordination_pattern(x):
    """
    To do: obtain the neighbors of an input atom position
    Args:
        x: the position of atoms
    Returns:
        the neighbors of the atoms, excluding the center atoms
    """
    return np.array([x+np.array([0.5,0.5,0]),
                     x+np.array([-0.5,0.5,0]),
                     x+np.array([0.5,-0.5,0]),
                     x+np.array([-0.5,-0.5,0]),
                     x+np.array([0.5,0,0.5]),
                     x+np.array([0.5,0,-0.5]),
                     x+np.array([-0.5,0,0.5]),
                     x+np.array([-0.5,0,-0.5]),
                     x+np.array([0,0.5,0.5]),
                     x+np.array([0,-0.5,0.5]),
                     x+np.array([0,0.5,-0.5]),
                     x+np.array([0,-0.5,-0.5]),
                    ])
def neighbors(x):
    """
    To do: obtain the occupied sites for a given cell
    Args:
        x: the position of cells
    Returns:
        the occupied sites in the cells
    """
    #define sites of fcc cell where x is the body center
    return np.array([x+np.array([0.5,0,0]),
                     x+np.array([-0.5,0,0]),
                     x+np.array([0,-0.5,0]),
                     x+np.array([0,0.5,0]),
                     x+np.array([0,0,0.5]),
                     x+np.array([0,0,-0.5]),      
                     x+np.array([0.5,0.5,0.5]),
                     x+np.array([-0.5,-0.5,0.5]),
                     x+np.array([0.5,-0.5,0.5]),
                     x+np.array([-0.5,0.5,0.5]),           
                     x+np.array([0.5,0.5,-0.5]),
                     x+np.array([-0.5,-0.5,-0.5]),
                     x+np.array([0.5,-0.5,-0.5]),
                     x+np.array([-0.5,0.5,-0.5])   
                    ])

# %%
position = []
for x in range(-100,100):
    for y in range(-100,100):
        for z in range(-100,100):
            if abs(x)+abs(y)+abs(z)<=16:
                position.append([x,y,z])
position = np.array(position)
print(len(position))
position = np.array(neighbors(position).flatten().reshape(-1,3))
position = np.unique(position,axis=0)
print(len(position))
position = position.tolist()

dipole_position = []
for x in range(-20,20):
    for y in range(-20,20):
        for z in range(-20,20):
            dipole_position.append([x,y,z])
dipole_position = np.array(dipole_position)
# Out:
# 6017
# 27438

# %%
# calculate how many atoms exist in individual dipoles
dipole_position_neighbor = neighbors(dipole_position)
atom_num = []
for index in range(dipole_position_neighbor.shape[1]):
    dipole_position_neighbor_tmp = dipole_position_neighbor[:,index].tolist()
    atom_num.append(sum([(i in position) for i in dipole_position_neighbor_tmp]))

# create a hashable dictionary for individual diples
atom_num_dic = {}
for i in range(len(dipole_position)):
    atom_num_dic[tuple(dipole_position[i].tolist())] = atom_num[i]

# %%
# initialie the change number
dipole_change_count = []

# %%
selected_dipoles = np.array(list(atom_num_dic.values())) == 14
scene = fresnel.Scene()
geometry = fresnel.geometry.Sphere(scene, N=len(dipole_position[selected_dipoles]), radius=np.sqrt(2)/2)
geometry.position[:] = dipole_position[selected_dipoles]
geometry.material = fresnel.material.Material(color=fresnel.color.linear([0.9, 0.714, 0.169]), roughness = 0.2)
scene.camera = fresnel.camera.Orthographic.fit(scene)
fresnel.preview(scene)

# %%
for step in range(1,20331):
    # read in the temporary steps 
    atoms_changes_type = np.loadtxt(f'./data3/atoms_changes_type{step*100}.csv',delimiter=',')
    atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
    count = 0 
    for change_type in atoms_changes_type:
        same_time_dipole_change_number = 0
        if change_type ==3:
            pass
        # addition event
        elif change_type ==1:
            # get the atoms to be added
            x = atoms_changes[count]
            # check if it is in the surface or at the corner
            index = np.where(np.around(x) != x)[0]
            # if at the surface
            if len(index) == 1:
                i = index[0]
                
                # get the top cell
                x_tmp = x.copy() # 1
                x_tmp[i] = x_tmp[i]+0.5
                atom_num_dic[tuple(x_tmp.tolist())] = atom_num_dic[tuple(x_tmp.tolist())] + 1

                # check if the dipoles are fully occupied now
                if atom_num_dic[tuple(x_tmp.tolist())] == 14:
                    dipole_change_count.append(np.concatenate((x_tmp,np.array([1]))))
                    same_time_dipole_change_number = same_time_dipole_change_number + 1
                    
                # get the bottom cell
                x_tmp = x.copy() #2
                x_tmp[i] = x_tmp[i]-0.5
                atom_num_dic[tuple(x_tmp.tolist())] = atom_num_dic[tuple(x_tmp.tolist())] + 1
                
                # check if the dipoles are fully occupied now
                if atom_num_dic[tuple(x_tmp.tolist())] == 14:
                    dipole_change_count.append(np.concatenate((x_tmp,np.array([1]))))
                    same_time_dipole_change_number = same_time_dipole_change_number + 1
            # if at the corner
            elif len(index)==3:
                x_temp = neighbors(x)
                for i in x_temp[-8:]:
                    atom_num_dic[tuple(i.tolist())] = atom_num_dic[tuple(i.tolist())] + 1
                    # check if the dipoles are fully occupied now
                    if atom_num_dic[tuple(i.tolist())] == 14:
                        dipole_change_count.append(np.concatenate((i,np.array([1]))))
                        same_time_dipole_change_number = same_time_dipole_change_number + 1
            else:
                pass
            
            # change the count number
            position.append(x.tolist())
            count = count +1
        # deletion event
        else:
            # get the atoms to be deleted
            x = atoms_changes[count]
            # check if it is in the surface or at the corner
            index = np.where(np.around(x) != x)[0]
            # if at the surface
            if len(index) == 1:
                i = index[0]
                # get the top cell
                x_tmp = x.copy()
                x_tmp[i] = x_tmp[i]+0.5
                atom_num_dic[tuple(x_tmp.tolist())] = atom_num_dic[tuple(x_tmp.tolist())] - 1
                
                # check if the dipoles are fully occupied now
                if atom_num_dic[tuple(x_tmp.tolist())] == 13:
                    dipole_change_count.append(np.concatenate((x_tmp,np.array([0]))))
                    same_time_dipole_change_number = same_time_dipole_change_number + 1
                    
                # get the bottom cell
                x_tmp = x.copy()
                x_tmp[i] = x_tmp[i]-0.5
                atom_num_dic[tuple(x_tmp.tolist())] = atom_num_dic[tuple(x_tmp.tolist())] - 1
                
                # check if the dipoles are fully occupied now
                if atom_num_dic[tuple(x_tmp.tolist())] == 13:
                    dipole_change_count.append(np.concatenate((x_tmp,np.array([0]))))
                    same_time_dipole_change_number = same_time_dipole_change_number + 1
            # if at the corner
            elif len(index)==3:
                x_temp = neighbors(x)
                for i in x_temp[-8:]:
                    atom_num_dic[tuple(i.tolist())] = atom_num_dic[tuple(i.tolist())] - 1
                    # check if the dipoles are fully occupied now
                    if atom_num_dic[tuple(i.tolist())] == 13:
                        dipole_change_count.append(np.concatenate((i,np.array([0]))))
                        same_time_dipole_change_number = same_time_dipole_change_number + 1
            else:
                pass            
            
            position.remove(x.tolist())
            count = count +1
        if same_time_dipole_change_number > 1:
            dipole_change_count_temp = dipole_change_count[-same_time_dipole_change_number:].copy()
            np.random.shuffle(dipole_change_count_temp)
            dipole_change_count[-same_time_dipole_change_number:] = dipole_change_count_temp
# Out:
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes20300.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes20800.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes21000.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes21100.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes21200.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes21800.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes22600.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes22700.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes22900.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes23400.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes23800.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes23900.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes24000.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes24500.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes24600.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes24700.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes24800.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes25000.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes25100.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes25200.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes25400.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes25700.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes25900.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes26100.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes26500.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes27200.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes27300.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes27400.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes27800.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes28000.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes28100.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes28300.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes28400.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes28500.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes28800.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes29000.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes29500.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes29600.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes29800.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes30000.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes30300.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes30600.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes30900.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes31000.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes31100.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes31200.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes31400.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes31500.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes31600.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes31800.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes32000.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes32300.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes32500.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes32600.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes32700.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes32800.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes33300.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes33400.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes33700.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes34100.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes34200.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes34600.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes34900.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes35000.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes35100.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes35400.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes35500.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes35600.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes35700.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes36000.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes36100.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes36200.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes36300.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes36500.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes36800.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes36900.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes37000.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes37100.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes37300.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes37400.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes37500.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes37600.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes37700.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes38000.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes38200.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes38400.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes38700.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes38800.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes39000.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes39200.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes39300.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes39400.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes39500.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes39600.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes39700.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes39800.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes39900.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes40000.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes40100.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes40300.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes40400.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes40500.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes40600.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes40700.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes40800.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes40900.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes41100.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes41200.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes41500.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes41600.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes41800.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes41900.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes42000.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes42100.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes42200.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes42300.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes42500.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes42600.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes42900.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes43000.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes43200.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes43300.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes43400.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes43500.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes43600.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes43700.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes43800.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes43900.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes44000.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes44200.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes44300.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes44400.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes44500.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes44600.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes44700.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes44800.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes45000.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes45100.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes45200.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes45300.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes45400.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes45500.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes45600.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes45700.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes45800.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes46000.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes46200.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes46300.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes46400.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes46600.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes46700.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes46800.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes47000.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes47200.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes47300.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes47500.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes47600.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes47700.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes47800.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes47900.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes48000.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes48100.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes48200.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes48300.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes48500.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes48700.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes48800.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes48900.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes49000.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes49100.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes49200.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes49300.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes49600.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes49700.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes49800.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes49900.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes50000.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes50100.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes50200.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes50300.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes50400.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes50500.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes50600.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes50800.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes50900.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes51000.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes51100.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes51200.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes51300.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes51400.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes51500.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes51600.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes51700.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes51800.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes51900.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes52000.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes52200.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes52300.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes52400.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes52500.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes52800.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes52900.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes53100.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes53200.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes53300.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes53400.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes53500.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes53600.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes53700.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes53800.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes53900.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes54000.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes54400.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes54600.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes54700.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes54800.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes54900.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes55000.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes55100.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes55200.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes55400.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes55700.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes55800.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes55900.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes56000.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes56100.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes56200.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# ...
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes1217000.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes1221800.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes1226300.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes1232300.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes1253200.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes1270700.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes1286800.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes1302400.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes1310200.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes1310500.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes1314800.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes1320800.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes1351500.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes1351700.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes1360400.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes1361200.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes1361800.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes1362800.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes1363200.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes1368800.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes1369800.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes1370100.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes1408600.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes1410700.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes1413500.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes1417900.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes1435700.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes1448600.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes1449800.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes1460000.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes1472700.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes1479500.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes1505100.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes1511500.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes1538600.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes1543400.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes1546200.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes1559500.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes1562600.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes1568100.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes1584700.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes1585400.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes1589800.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes1590600.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes1594000.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes1676400.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes1682300.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes1694900.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes1711800.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes1717800.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes1719600.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes1721500.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes1728400.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes1746300.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes1750800.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes1775900.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes1778900.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes1807800.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes1826500.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes1835600.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes1848800.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes1854800.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes1857700.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes1857800.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes1859000.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes1865800.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes1875500.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes1894900.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes1896000.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes1898000.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes1898200.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes1912400.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes1973600.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes1977500.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)
# /tmp/ipykernel_3598944/1189029828.py:4: UserWarning: loadtxt: Empty input file: "./data3/atoms_changes1979800.csv"
#   atoms_changes =  np.loadtxt(f'./data3/atoms_changes{step*100}.csv',delimiter=',').reshape(-1,3)

# %% [markdown]
# # Validate the structure

# %%
# calculate how many atoms exist in individual dipoles
atom_num2 = []
for index in range(dipole_position_neighbor.shape[1]):
    dipole_position_neighbor_tmp = dipole_position_neighbor[:,index].tolist()
    atom_num2.append(sum([(i in position) for i in dipole_position_neighbor_tmp]))

# create a hashable dictionary for individual diples
atom_num_dic2 = {}
for i in range(len(dipole_position)):
    atom_num_dic2[tuple(dipole_position[i])] = atom_num2[i]

# %%
abs(np.array(list(atom_num_dic2.values())) - np.array(list(atom_num_dic.values()))).max()
# Out:
# 0

# %% [markdown]
# # Show the structure

# %%
scene = fresnel.Scene()
geometry = fresnel.geometry.Sphere(scene, N=len(position), radius=np.sqrt(2)/4)
geometry.position[:] = position
geometry.material = fresnel.material.Material(color=fresnel.color.linear([0.9, 0.714, 0.169]), roughness = 0.2)
scene.camera = fresnel.camera.Orthographic.fit(scene)
fresnel.preview(scene)

# %%
selected_dipoles = np.array(list(atom_num_dic.values())) == 14
scene = fresnel.Scene()
geometry = fresnel.geometry.Sphere(scene, N=len(dipole_position[selected_dipoles]), radius=np.sqrt(2)/2)
geometry.position[:] = dipole_position[selected_dipoles]
geometry.material = fresnel.material.Material(color=fresnel.color.linear([0.9, 0.714, 0.169]), roughness = 0.2)
scene.camera = fresnel.camera.Orthographic.fit(scene)
fresnel.preview(scene)

# %%
# Generate the trajecotry according to the dipole change which is recorded above
dipole_position = dipole_position.tolist()
dipole_change_count = np.array(dipole_change_count)
changed_dipole_index = [dipole_position.index(dipole_change_count[i][0:3].tolist()) for i in range(len(dipole_change_count))]

# %%
# get the initial dipole position
position = []
for x in range(-100,100):
    for y in range(-100,100):
        for z in range(-100,100):
            if abs(x)+abs(y)+abs(z)<=16:
                position.append([x,y,z])
position = np.array(position)
initial_dipole_index = [dipole_position.index(position[i].tolist()) for i in range(len(position))]

# %%
# check if all the changed dipoles are contained in the initial dipole configuration
# if so, we will just use the original dipole configuration to set up the system
print(sum([i in initial_dipole_index for i in np.unique(changed_dipole_index)]))
print(len(np.unique(changed_dipole_index)))
# Out:
# 5598
# 5598

# %%
# get the changed dipole index with respect to the new dipole configuration
position = position.tolist()
changed_dipole_index = [position.index(dipole_change_count[i][0:3].tolist()) for i in range(len(dipole_change_count))]
changed_dipole_index = np.array(changed_dipole_index)
changed_dipole_type = dipole_change_count[:,3]

# %%
Au_dipoles = np.ones(len(position),dtype = bool)
for i in range(len(changed_dipole_index)):
    if changed_dipole_type[i] == 1:
        Au_dipoles[changed_dipole_index[i]] = True
    else:
        Au_dipoles[changed_dipole_index[i]] = False

# %%
scene = fresnel.Scene()
geometry = fresnel.geometry.Sphere(scene, N=len(np.array(position)[Au_dipoles]), radius=np.sqrt(2)/2)
geometry.position[:] = np.array(position)[Au_dipoles]
geometry.material = fresnel.material.Material(color=fresnel.color.linear([0.9, 0.714, 0.169]), roughness = 0.2)
scene.camera = fresnel.camera.Orthographic.fit(scene)
fresnel.preview(scene)

# %%
np.savetxt('./data3/changed_dipole_index.csv',changed_dipole_index,delimiter=',')
np.savetxt('./data3/changed_dipole_type.csv',changed_dipole_type,delimiter=',')
